# %%
from utils import *
rews_dqn, wins_dqn = get_lists_to_plot("mario/dqn/dqn_train_freq_3")
rews_ddqn_freq1, wins_ddqn_freq1 = get_lists_to_plot("mario/dqn/train_freq_1")
rews_ddqn_freq3, wins_ddqn_freq3 = get_lists_to_plot("mario/dqn/train_freq_3")

# %%
plot_average_reward(rews_dqn, title="Episodes trained vs. Average Rewards", n_average=1)

# %%
list_infos = [rews_dqn, rews_ddqn_freq1, rews_ddqn_freq3]
plot_error_lineplots(list_infos, 500, xlabel="Episode", ylabel="Rewards", names=["DQN - Train freq(1)", "DDQN - Train freq(1)", "DDQN - Train freq(3)"])
# Out:
# e:\10mociclo\Applied\RL_Sonic-TheHedgehog\results\utils.py:38: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.lineplot(x=xlabel, y=ylabel, data=combined_df, ci="sd", hue="Model")

# %%
list_infos = [wins_dqn, wins_ddqn_freq1, wins_ddqn_freq3]
plot_error_lineplots(list_infos, 500, xlabel="Episode", ylabel="Win rate", names=["DQN - Train freq(1)", "DDQN - Train freq(1)", "DDQN - Train freq(3)"])
# Out:
# e:\10mociclo\Applied\RL_Sonic-TheHedgehog\results\utils.py:38: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.lineplot(x=xlabel, y=ylabel, data=combined_df, ci="sd", hue="Model")

# %%
#Smooth
smooth = 10
y = np.ones(smooth)
x = np.asarray(rews_dq[0])
z = np.ones(len(x))
smoothed_x = np.convolve(x,y,'same') / np.convolve(z,y,'same')
print(len(smoothed_x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 smooth = 10
#       3 y = np.ones(smooth)
# ----> 4 x = np.asarray(rews_dq[0])
#       5 z = np.ones(len(x))
#       6 smoothed_x = np.convolve(x,y,'same') / np.convolve(z,y,'same')
#
# NameError: name 'rews_dq' is not defined

# %%
plot_error_lineplots([rews_dqn], 50, xlabel="Episode", ylabel="Rewards", names=["DQN"])
# Out:
# e:\10mociclo\Applied\RL_Sonic-TheHedgehog\results\utils.py:38: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.lineplot(x=xlabel, y=ylabel, data=combined_df, ci="sd", hue="Model")
