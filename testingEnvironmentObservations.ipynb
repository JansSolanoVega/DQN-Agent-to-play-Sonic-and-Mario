# %%
import retro
from utils import *
import numpy as np
from wrappers import *

env = get_env(game="sonic", level="LabyrinthZone.Act1")
env.reset()

next_state, reward, done, info = env.step(get_action_sample(env))
print(f"{next_state.shape},\n {reward},\n {done},\n {info}")
# Out:
# (224, 320, 3),
#  0.0,
#  False,
#  {'level_end_bonus': 0, 'rings': 0, 'score': 0, 'zone': 1, 'act': 0, 'screen_x_end': 6591, 'screen_y': 12, 'lives': 3, 'x': 96, 'y': 108, 'screen_x': 0}

# %%
# Apply Wrappers to environment
env = apply_wrappers(env, skip=4, gray_scale=True, shape=(156, 156), num_stack=4)
env.reset()

# %%
next_state, reward, done, info = env.step(get_action_sample(env))
print(f"{next_state.shape},\n {reward},\n {done},\n {info}")
plot_sequence_observations(next_state)
# Out:
# (6, 156, 156),
#  0.0,
#  False,
#  {'level_end_bonus': 0, 'rings': 0, 'score': 0, 'zone': 1, 'act': 0, 'screen_x_end': 6591, 'screen_y': 12, 'lives': 3, 'x': 96, 'y': 108, 'screen_x': 0}

# %%
env.close()
