# %%
import retro
from utils import *
import numpy as np
from wrappers import *

env = get_env(game="mario")#, level="LabyrinthZone.Act1")
env.reset()

next_state, reward, done, info = env.step(get_action_sample(env))
print(f"{next_state.shape},\n {reward},\n {done},\n {info}")
# Out:
# (240, 256, 3),
#  0.0,
#  False,
#  {'coins': 0, 'flag_get': False, 'life': 2, 'score': 0, 'stage': 1, 'status': 'small', 'time': 400, 'world': 1, 'x_pos': 40, 'y_pos': 79}

# %%
# Apply Wrappers to environment
env = apply_wrappers(env, skip=4, gray_scale=True, shape=(156, 156), num_stack=4)
env.reset()

# %%
next_state, reward, done, info = env.step(get_action_sample(env))
print(f"{next_state.shape},\n {reward},\n {done},\n {info}")
plot_sequence_observations(next_state)
# Out:
# (4, 156, 156),
#  0.0,
#  False,
#  {'coins': 0, 'flag_get': False, 'life': 2, 'score': 0, 'stage': 1, 'status': 'small', 'time': 400, 'world': 1, 'x_pos': 40, 'y_pos': 79}

# %%
next_state[0]
# Out:
# tensor([[0.5476, 0.5476, 0.5476,  ..., 0.5476, 0.5476, 0.5476],
#         [0.5476, 0.5476, 0.5476,  ..., 0.5476, 0.5476, 0.5476],
#         [0.5476, 0.5476, 0.5476,  ..., 0.5476, 0.5476, 0.5476],
#         ...,
#         [0.7481, 0.5153, 0.3536,  ..., 0.4862, 0.4862, 0.2049],
#         [0.6902, 0.5247, 0.5807,  ..., 0.4862, 0.4516, 0.1431],
#         [0.4403, 0.1891, 0.1891,  ..., 0.1891, 0.1445, 0.1719]])

# %%
env.close()
